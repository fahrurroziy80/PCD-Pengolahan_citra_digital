# %% [markdown]
# # NumPy Introduction

# %% [markdown]
# NumPy is a Python library used for working with arrays.
#
# It also has functions for working in domain of linear algebra, fourier transform, and matrices.
#
# NumPy was created in 2005 by Travis Oliphant. It is an open source project and you can use it freely.
#
# NumPy stands for Numerical Python.

# %%
list2D = [[10,20,30, 90,100],[40,20,30, 100,99],[70,90,100, 120,80],[0,10,20,30,77],[10,20,30, 90,11]]

# %%
type(list2D)
# Out:
# list

# %%
list2D
# Out:
# [[10, 20, 30, 90], [40, 20, 30, 100], [70, 90, 100, 120], [0, 10, 20, 30]]

# %%
list2D.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 list2D.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %% [markdown]
# # Why Use NumPy?
#
# In Python we have lists that serve the purpose of arrays, but they are slow to process.
#
# NumPy aims to provide an array object that is up to 50x faster than traditional Python lists.
#
# The array object in NumPy is called ndarray, it provides a lot of supporting functions that make working with ndarray very easy.
#
# Arrays are very frequently used in data science, where speed and resources are very important.

# %%
import numpy as np

# %%
x = np.array(list2D, np.int32)

# %%
x
# Out:
# array([[ 10,  20,  30,  90, 100],
#        [ 40,  20,  30, 100,  99],
#        [ 70,  90, 100, 120,  80],
#        [  0,  10,  20,  30,  77],
#        [ 10,  20,  30,  90,  11]])

# %%
tt = x[2:3,2:3] # vaariabel[mau ambil koordinat mulai baris : berapa baris, 
# Koordinat kolom : berapa kolom]
print(tt)
# Out:
# [[100]]

# %% [markdown]
# ### y = x[:,1:]
# print(y)

# %%
x[3][3]
xx = x[:,3]
print(xx)
yy = x[2,:]
print(yy)
zz = x[1:,1]
print(zz)
pp = x[1:,3]
print(pp)
# Out:
# [ 90 100 120  30]
# [ 70  90 100 120]
# [20 90 10]
# [100 120  30]

# %%
y = x[1,:]
print(y)
# Out:
# [ 40  20  30 100]

# %%
import skimage

print("sukses")
# Out:
# sukses

# %%
import numpy as np
import skimage
import skimage.io
import matplotlib.pyplot as plt
print("selesa")
# Out:
# selesa

# %%
image = skimage.io.imread("mhs.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 image = skimage.io.imread("Documents/PENGOLAHAN-CITRA-DIGITAL/PERTEMUAN 2/mhs.jpg")
#
# File ~\myenv\Lib\site-packages\skimage\_shared\utils.py:328, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     324     elif self.new_name is not None:
#     325         # Assign old value to new one
#     326         kwargs[self.new_name] = deprecated_value
# --> 328 return func(*args, **kwargs)
#
# File ~\myenv\Lib\site-packages\skimage\io\_io.py:82, in imread(fname, as_gray, plugin, **plugin_args)
#      79         plugin = 'tifffile'
#      81 with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ---> 82     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      84 if not hasattr(img, 'ndim'):
#      85     return img
#
# ...

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (960, 1280, 3)

# %%
from skimage.color import rgb2gray

grayscale = rgb2gray(image)

# %%
plt.imshow(grayscale, 'gray')

# %%
grayscale.shape
# Out:
# (960, 1280)

# %%
type(grayscale)
# Out:
# numpy.ndarray

# %%
crop = grayscale[100:400,900:1120]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 crop = grayscale[100:400,900:1120]
#
# NameError: name 'grayscale' is not defined

# %%
plt.imshow(crop, 'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.imshow(crop, 'gray')
#
# NameError: name 'plt' is not defined
